# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ### Import functions unique to this project

# %%
from master_functions import get_car_urls
from master_functions import make_model_df

# %% [markdown]
# ## Bentley - Create master dataframe for all Bentley models

# %% [markdown]
# This worksheet is intended to build a datafame for all **Bentley** cars.  There are some 'quirks' in how the data is structured from its source on https://www.fueleconomy.gov/, so more manual steps are taken below to check files for issues, combine first what is 'normal' and then add in those that required special attention.

# %% [markdown]
# **Step #1:** Create unique urls for every Bentley model for the years 1984 - 2021<br>
# - Uses `get_car_urls` from master function, Inputs: (car_make, [list of all models])

# %%
bentley_urls = get_car_urls('Bentley',
                            ['Arnage','Azure','Bentayga','Brooklands',
                             'Continental','Continental Flying Spur',
                             'Continental GT Convertible',
                             'Continental GT Supersports',
                             'Continental Superports Convertible',
                             'Flying Spur','Mulsanne','Turbo RT'
                            ])

# %% [markdown]
# -

# %% [markdown]
# **Step #2:** Get length of list created in Step 1.  This number will be how many times you run the function in Step 3 to check all of the urls<br>

# %%
# Verify number of urls and use this number
# to know how many urls need to 'check below'

len(bentley_urls)
# Out:
# 12

# %% [markdown]
# -

# %% [markdown]
# **Step #3:** Check all of the urls you just created.<br>
# - If works, add to `bentley_okay_modelranks` list in Step 4
# - If does not work, add to 'problem' URLs string in Step 4

# %%
# Test area for each url with audi_urls[index]
# by seeing if data appears correctly

make_model_df('Bentley',bentley_urls[11])
# Out:
#    year     make     model  capacity_liters  cylinders transmission  \
# 0  1999  Bentley  Turbo RT              6.8          8    Automatic
# 1  1998  Bentley  Turbo RT              6.7          8    Automatic
#
#   trans_speed          fuel_type  gg_emissions  mpg
# 0           4   Premium Gasoline           741   12
# 1           4   Premium Gasoline           741   12

# %% [markdown]
# -

# %% [markdown]
# **Step #4:** From Step 3 above you should have populated this section so URLs either are in the category of "problem" or "normal"

# %%
#'Problem' URLs
'''
bentley_urls[2]
bentley_urls[5]
bentley_urls[6]
bentley_urls[9]

'''

#'Normal' URLs

audi_okay_modelranks = [0,1,3,4,7,8,
                        10,11
                       ]

# %% [markdown]
# -

# %% [markdown]
# **Step #5:** Create dfs for all 'okay' urls and place each into a master list
# - Automate where possible, but some may need to be added one by one to avoid 'problem' urls

# %%
bentley_0 = make_model_df('Bentley',bentley_urls[0])
bentley_1 = make_model_df('Bentley',bentley_urls[1])
bentley_3 = make_model_df('Bentley',bentley_urls[3])
bentley_4 = make_model_df('Bentley',bentley_urls[4])
bentley_7 = make_model_df('Bentley',bentley_urls[7])
bentley_8 = make_model_df('Bentley',bentley_urls[8])
bentley_10 = make_model_df('Bentley',bentley_urls[10])
bentley_11 = make_model_df('Bentley',bentley_urls[11])

# %%
bentley_dfs = [bentley_0,
               bentley_1,
               bentley_3,
               bentley_4,
               bentley_7,
               bentley_8,
               bentley_10,
               bentley_11
              ]

len(bentley_dfs)
# Out:
# 8

# %% [markdown]
# -

# %% [markdown]
# **Step #6:** Concatenate all of the 'normal' Bentley model dfs into one master dataframe

# %%
bentley_dfs = pd.concat(bentley_dfs, ignore_index=True)

bentley_dfs
# Out:
#       year     make                       model  capacity_liters  cylinders  \
# 0   1999.0  Bentley                      Arnage              4.4        8.0
# 1   2000.0  Bentley                      Arnage              4.4        8.0
# 2   2001.0  Bentley                      Arnage              6.8        8.0
# 3   2000.0  Bentley                      Arnage              6.7        8.0
# 4   2008.0  Bentley                      Arnage              6.7        8.0
# 5   2007.0  Bentley                      Arnage              6.7        8.0
# 6   2009.0  Bentley                      Arnage              6.7        8.0
# 7   2007.0  Bentley                  Arnage LWB              6.7        8.0
# 8   2009.0  Bentley                   Arnage RL              6.7        8.0
# 9   2008.0  Bentley                   Arnage RL              6.7        8.0
# 10  2003.0  Bentley                       Azure              6.8        8.0
# 11  2001.0  Bentley                       Azure              6.8        8.0
# 12  2000.0  Bentley                       Azure              6.7        8.0
# 13  1999.0  Bentley                       Azure              6.8        8.0
# 14  1998.0  Bentley                       Azure              6.7        8.0
# 15  2007.0  Bentley                       Azure              6.7        8.0
# 16  2010.0  Bentley                       Azure              6.8        8.0
# 17  2009.0  Bentley                       Azure              6.7        8.0
# 18  2008.0  Bentley                       Azure              6.7        8.0
# 19  1998.0  Bentley                Brooklands R              6.7        8.0
# 20  2009.0  Bentley                  Brooklands              6.7        8.0
# 21  2010.0  Bentley                  Brooklands              6.8        8.0
# 22  1999.0  Bentley           Brooklands R Limo              6.8        8.0
# 23  1998.0  Bentley           Brooklands R Limo              6.7        8.0
# 24  2020.0  Bentley              Continental GT              4.0        8.0
# 25  2021.0  Bentley  Continental GT Convertible              4.0        8.0
# 26  2017.0  Bentley              Continental GT              4.0        8.0
# 27  2016.0  Bentley              Continental GT              4.0        8.0
# 28  2015.0  Bentley              Continental GT              4.0        8.0
# 29  2014.0  Bentley              Continental GT              4.0        8.0
# 30  2013.0  Bentley              Continental GT              4.0        8.0
# 31  2014.0  Bentley             Continental GTC              4.0        8.0
# 32  2013.0  Bentley             Continental GTC              4.0        8.0
# 33  2015.0  Bentley           Continental GT3-R              4.0        8.0
# 34  2018.0  Bentley                    Mulsanne              6.8        8.0
# 35  2017.0  Bentley                    Mulsanne              6.8        8.0
# 36  2016.0  Bentley                    Mulsanne              6.8        8.0
# 37  2015.0  Bentley                    Mulsanne              6.8        8.0
# 38  2014.0  Bentley                    Mulsanne              6.8        8.0
# 39  2013.0  Bentley                    Mulsanne              6.8        8.0
# 40  2012.0  Bentley                    Mulsanne              6.8        8.0
# 41  2011.0  Bentley                    Mulsanne              6.8        8.0
# 42  2017.0  Bentley                Mulsanne EWB              6.8        8.0
# 43  2020.0  Bentley                    Mulsanne              6.8        8.0
# 44  1999.0  Bentley                    Turbo RT              6.8        8.0
# 45  1998.0  Bentley                    Turbo RT              6.7        8.0
#
#    transmission trans_speed          fuel_type  gg_emissions   mpg
# 0     Automatic           5   Premium Gasoline         684.0  13.0
# 1     Automatic           5   Premium Gasoline         741.0  12.0
# 2     Automatic           4   Premium Gasoline         741.0  12.0
# 3     Automatic           4   Premium Gasoline         741.0  12.0
# 4     Automatic          S6   Premium Gasoline         808.0  11.0
# 5     Automatic          S6   Premium Gasoline         808.0  11.0
# 6     Automatic          S6   Premium Gasoline         808.0  11.0
# 7     Automatic          S6   Premium Gasoline         808.0  11.0
# 8     Automatic          S6   Premium Gasoline         808.0  11.0
# 9     Automatic          S6   Premium Gasoline         808.0  11.0
# 10    Automatic           4   Premium Gasoline         741.0  12.0
# 11    Automatic           4   Premium Gasoline         741.0  12.0
# 12    Automatic           4   Premium Gasoline         741.0  12.0
# 13    Automatic           4   Premium Gasoline         741.0  12.0
# 14    Automatic           4   Premium Gasoline         741.0  12.0
# 15    Automatic          S6   Premium Gasoline         808.0  11.0
# 16    Automatic           6   Premium Gasoline         808.0  11.0
# 17    Automatic          S6   Premium Gasoline         808.0  11.0
# 18    Automatic          S6   Premium Gasoline         808.0  11.0
# 19    Automatic           4   Premium Gasoline         741.0  12.0
# 20    Automatic          S6   Premium Gasoline         808.0  11.0
# 21    Automatic           6   Premium Gasoline         808.0  11.0
# 22    Automatic           4   Premium Gasoline         808.0  11.0
# 23    Automatic           4   Premium Gasoline         808.0  11.0
# 24    Automatic       AM-S8   Premium Gasoline         469.0  19.0
# 25    Automatic       AM-S8   Premium Gasoline         468.0  19.0
# 26    Automatic          S8   Premium Gasoline         475.0  18.0
# 27    Automatic          S8   Premium Gasoline         494.0  18.0
# 28    Automatic          S8   Premium Gasoline         494.0  18.0
# 29    Automatic          S8   Premium Gasoline         505.0  18.0
# 30    Automatic          S8   Premium Gasoline         505.0  18.0
# 31    Automatic          S8   Premium Gasoline         535.0  17.0
# 32    Automatic          S8   Premium Gasoline         532.0  17.0
# 33    Automatic          S8   Premium Gasoline         535.0  17.0
# 34    Automatic          S8   Premium Gasoline         652.0  14.0
# 35    Automatic          S8   Premium Gasoline         652.0  14.0
# 36    Automatic          S8   Premium Gasoline         652.0  14.0
# 37    Automatic          S8   Premium Gasoline         688.0  13.0
# 38    Automatic          S8   Premium Gasoline         688.0  13.0
# 39    Automatic          S8   Premium Gasoline         688.0  13.0
# 40    Automatic          S8   Premium Gasoline         684.0  13.0
# 41    Automatic          S8   Premium Gasoline         684.0  13.0
# 42    Automatic          S8   Premium Gasoline         692.0  13.0
# 43    Automatic          S8   Premium Gasoline         749.0  12.0
# 44    Automatic           4   Premium Gasoline         741.0  12.0
# 45    Automatic           4   Premium Gasoline         741.0  12.0

# %% [markdown]
# -

# %% [markdown]
# **Step #7:** Pickle the dataframe made in Step 6 of all Audi models with 'normal' dataframes
# - Will now be saved so further work on dataframe can start at this place

# %%
with open('pickles/bentley_dfs.pickle', 'wb') as to_write:
    pickle.dump(bentley_dfs, to_write)

# %% [markdown]
# -

# %% [markdown]
# **Step #8:** Un-pickle the dataframe made in Step 7 of all Audi models with 'normal' dataframes

# %%
with open('pickles/bentley_dfs.pickle','rb') as read_file:
    bentley_dfs = pickle.load(read_file)
